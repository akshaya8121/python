# %%
import numpy as np

# %%
np.random.randint(18,20,200)
# Out:
# array([18, 18, 19, 18, 19, 19, 19, 19, 18, 18, 18, 18, 19, 18, 19, 18, 19,
#        19, 19, 19, 19, 19, 19, 18, 18, 18, 19, 19, 18, 19, 18, 19, 18, 19,
#        19, 18, 19, 19, 19, 19, 18, 18, 18, 18, 18, 18, 19, 18, 19, 18, 18,
#        18, 19, 19, 18, 19, 19, 19, 18, 18, 19, 19, 19, 19, 18, 19, 18, 18,
#        19, 18, 18, 19, 19, 19, 19, 18, 18, 19, 19, 19, 19, 19, 18, 19, 19,
#        19, 18, 19, 19, 18, 18, 18, 18, 18, 19, 19, 19, 19, 19, 19, 18, 18,
#        18, 19, 18, 19, 18, 18, 19, 18, 19, 18, 18, 19, 18, 18, 19, 19, 19,
#        19, 19, 18, 18, 18, 18, 19, 19, 19, 19, 18, 18, 18, 19, 19, 19, 18,
#        19, 19, 18, 18, 19, 19, 19, 19, 19, 18, 18, 19, 19, 18, 18, 18, 18,
#        19, 19, 18, 19, 18, 19, 19, 18, 19, 19, 19, 18, 19, 18, 19, 18, 19,
#        19, 19, 19, 18, 19, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 19, 18,
#        19, 19, 19, 18, 19, 18, 18, 18, 19, 18, 18, 19, 18])

# %%
np.random.normal(18,21,200)
# Out:
# array([-15.49751798,  41.45103618,  -8.34450915,  -8.41346487,
#         38.14208747,  -7.98864736,  28.37243246,  14.1304576 ,
#         39.07576932,  27.27735394,   0.42464467,  27.42477224,
#         21.84804375,  23.31113921,  27.27780142,  21.29756757,
#         34.43580789, -17.80448106,  25.65811061,  28.50382775,
#         12.8060809 ,  13.5386463 , -12.79959452,  15.30066131,
#         35.81029154,  -1.92629565,  -5.90180883,  12.44322421,
#          2.84560895,  43.12991393,  13.47156269,  -5.21184463,
#         12.84850211,  56.99829091,  12.13210139,   5.07990996,
#        -10.61838892,  11.60710246,  30.17572559, -10.39217618,
#         11.10483415,  19.80085089,  26.31955323,  16.2895219 ,
#        -11.86154925,  52.68814227,   6.71440839,  22.27557382,
#          8.74631069,  29.24590694,  34.54005452,  36.15437961,
#         30.47545145,  26.5903675 ,  60.64879869,  30.99015554,
#         50.85871329,  28.35246791,  36.59547478,  15.79490783,
# ...

# %%
h=[38,20,5,8,9]
h
# Out:
# [38, 20, 5, 8, 9]

# %%
d=[]
for i in h:
    d.append(i+5)
d
# Out:
# [43, 25, 10, 13, 14]

# %%
s=(6,2,3,9,7,5,8)
s
# Out:
# (6, 2, 3, 9, 7, 5, 8)

# %%
tuple(x**2 for x in s)
# Out:
# (36, 4, 9, 81, 49, 25, 64)

# %%
y = list(s)
k = []
for i in y:
  k.append(i**2)
s=tuple(k)
s
# Out:
# (1679616, 256, 6561, 43046721, 5764801, 390625, 16777216)

# %%
m=[]
for i in s:
  if i>30:
    m.append(i)

# %%
m
# Out:
# [1679616, 256, 6561, 43046721, 5764801, 390625, 16777216]

# %%
arr=np.array([20,50,30,70,80,40,36,23,98])

# %%
arr
# Out:
# array([20, 50, 30, 70, 80, 40, 36, 23, 98])

# %%
arr**2
# Out:
# array([ 400, 2500,  900, 4900, 6400, 1600, 1296,  529, 9604])
